# %%
## Text Loader
from langchain_community.document_loaders import TextLoader
loader = TextLoader('speech.txt')
loader

# %%
text_documents = loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Modi was born and raised in Vadnagar, in present-day Gujarat, where he completed his secondary education. He was introduced to the RSS at the age of eight and became a full-time worker for the organisation in Gujarat in 1971. In 1985, he was assigned to the BJP and rose through the party hierarchy, becoming general secretary in 1998. In 2001, Modi was appointed chief minister of Gujarat and elected to the legislative assembly soon after. His administration has been criticised for its management of the 2002 Gujarat riots, during which official records reported a little over 1,000 deaths, mostly Muslims, while independent estimates placed the toll at around 2,000. A Special Investigation Team appointed by the Supreme Court of India in 2012 found no evidence to initiate prosecution proceedings against him. While his policies as chief minister were credited with encouraging economic growth, his administration was also criticised for failing to significantly improve health, poverty, and education indicators in the state.\n\nIn the 2014 Indian general election, Modi led the BJP to a parliamentary majority, the first for any party since 1984. His administration increased foreign investment and reduced spending on healthcare, education, and social-welfare programs. Modi launched a high-profile sanitation campaign and introduced changes that weakened or abolished certain environmental and labour regulations. His demonetisation policy in 2016 and the implementation of the Goods and Services Tax in 2017 were widely debated and controversial. In 2019, his administration authorised an airstrike against a suspected terrorist training facility in Pakistan; the action carried strong nationalist appeal. Modi won re-election in 2019. In his second term, his government revoked the special status of Jammu and Kashmir and introduced the Citizenship Amendment Act, both of which prompted widespread protests and unrest. The 2020 Delhi riots resulted in violence and casualties, particularly among Muslims. Three farm laws introduced by his administration triggered major protests by farmers and were eventually repealed. Modi also led India’s response to the COVID-19 pandemic, during which the World Health Organization estimated that millions of Indians died. In the 2024 general election, Modi’s party lost its outright majority and formed a coalition government under the National Democratic Alliance. Following a terrorist attack in Indian-administered Jammu and Kashmir, Modi oversaw India’s involvement in the 2025 India–Pakistan conflict, which eventually resulted in a ceasefire.')]

# %%
## reading a pdf file
from langchain_community.document_loaders import PyPDFLoader
pdfRead = PyPDFLoader('aryadbmsreport.pdf')
pdfRead

# %%
pdfReader = pdfRead.load()
pdfReader
# Out:
# Ignoring wrong pointing object 18 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Ignoring wrong pointing object 175 0 (offset 0)
# Ignoring wrong pointing object 176 0 (offset 0)
# [Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 0, 'page_label': '1'}, page_content='Nitte Meenakshi  Institute  of Technology\nYelahanka, Bangalore- 560064, Karnataka- India.\nAn Autonomous Institution with A+ Grade by NAAC UGC, Approved by VTU, UGC, AICTE, Govt. of India.\nDepartment of Electronics and Communication Engineering\nAY: 2025-2026\nA Report on the Experiments of the Ability Enhancement Course\nDatabase  Management  Systems  Lab (22ECA563)\nSubmitted By\nArya Anand Pathak 1NT23EC022\nUnder the Guidance of\nDr Ramachandra AC\nProfessor\nDepartment of ECE, NMIT'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 1, 'page_label': '2'}, page_content='Contents\n1.  Introduction to DBMS 01\n2.  Creating Databases and Tables in MySQL 04\n3.   Primary Key, and Foreign Key integrity 07\n4.  ALTER, UPDATE, DELETE 09\n5.  Performing JOINS in SQL 11\n6.  Functions in SQL: MAX(), MIN(), AV G ( ) and COUNT() 13\n7.  Integrity  Constraints  15\n8.  Implementation  of Views 17\n9.  Implementation  of Triggers  18\n10.Referential  Integrity  20\n11.Creating Users And Assigning Roles 22\n12.Conclusion  24'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 2, 'page_label': '3'}, page_content='Experiment  1: Introduction  to DBMS\n\x00 What is a Database?\x00\nA database  is an organized  collection  of data that is structured  to facilitate efficient  storage,  \nretrieval,  and management  by a computer  system.  It allows  users  to store large amounts  of \ninformation  in a systematic  manner,  enabling  quick  access  and manipulation  of that data.\n\x00   What is a Database  Management  System? \x00\nA Database  Management  System  (DBMS)  is a software  platform  designed  to facilitate  the \ncreation,  management,  and  manipulation  of  databases.  It serves  as  an  intermediary  \nbetween   users   and   the  database,   allowing   for   efficient   data   storage,   retrieval,   and  \nmanagement.  A DBMS makes it easier to organize and control the data stored in a database, \nwith examples including MySQL, PostgreSQL, and MongoDB.\n\x00   Relational DBMS (RDBMS):\x00\nAn  RDBMS  is a type  of database  management  system  that  organizes  data  into  tables  \n(relations)  consisting  of rows  and columns.  It uses  Structured  Query  Language  (SQL)  to \nmanage  and manipulate  data. Relationships  between  tables  are established  using  keys.\nWe will be looking into two types of models used for Relational DBMS: Relational Model and \nEntity-Relationship  Model.\n1.  Entity-Relationship  Model  (ER  Model):\nThe  ER  model  is a design  framework  used  to visualize  and  structure  the  data  before  \nimplementing  it in a database.  It represents  data  as entities,  attributes,  and  relationships.  \nER diagrams  are used to depict this model graphically,  aiding  in database  design.\nSymbols used in ER model:\n\x00 Rectangles:  Rectangles  represent  Entities  in the ER Model.\n\x00 Ellipses:  Ellipses  represent  Attributes in the ER Model.\n\x00 Diamond:  Diamonds  represent  Relationships among  Entities.\n1'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 3, 'page_label': '4'}, page_content='\x00  What  is an Entity?\nAn Entity  may  be an object  with  a physical  existence  – a particular  person,  car, house,  or \nemployee  – or it may  be an object  with  a conceptual  existence  – a company,  a job,  or a \nuniversity  course.\n\x00  What  is an Attribute?\nAttributes  are the properties  that define the entity type. For example,  USN, Name, Age, and \nAddress  are the attributes  that  define  entity  type  Student.  In ER diagram,  the attribute  is \nrepresented  by an oval.\n\x00  What  is a Relationship?\nA Relationship  represents  the association  between  entity types. For example,  ‘Enrolled in’ \nis a relationship  type  that exists between  entity  type Student  and Course.\nDiagram representing a simple Entity-Relationship model.\n2. Relational  Model\nThe  relational  model  is a  framework  for  organizing  data  in an  RDBMS.  Data   is \nrepresented  as tables  (relations)  with  rows  and columns.  Each  table  has a unique  key \nto identify  records,  known  as primary  key and relationships  between  tables  are based  \non shared  attributes.\nTerminologies:\n\x00 Attribute:  Attributes  are the properties  that define an entity. e.g.; Name, USN, Address.\n\x00 Tuple: Each  row in the relation  is known  as a tuple.\n\x00 Relation  Schema:  A  relation   schema   defines   the   structure   of  the   relation   and\nrepresents  the name  of the relation  with  its attributes.\n\x00 Relation  Instance:  The  set  of tuples  of  a relation  at a particular  instance  of  time  is\ncalled a relation instance.\n\x00 Degree:  The number  of attributes  in the relation  is known  as the degree  of the relation.\n\x00 Cardinality:  The  number  of tuples  in a relation is known  as cardinality.\n\x00 Column:  The column  represents  the set of values  for a particular  attribute.\n\x00 NULL Values: The value which is not known or unavailable is called a NULL value. It is\nrepresented  by blank  space.\n2'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 4, 'page_label': '5'}, page_content='About MySQL\nMySQL  server  is an open-source  relational  database  management  system.  Databases  and  \nrelated  tables  are the main  component  of many  websites  as the data  is stored  and exchanged  \nover the web. Almost all social networking  websites  like Facebook,  Twitter and Google depend \non MySQL  data  which  are  designed  and  optimized  for  such  purpose.  For  all these  reasons,  \nMySQL server becomes  the default choice for web applications.\nAdvantages of MySQL:\n\x00 Fast and high-performance  database.\n\x00 Easy to use, maintain  and administer.\n\x00 Easily available  and maintain  integrity of database.\n\x00 Provides scalability, usability and reliability.\n\x00 Low-cost  hardware.\n\x00 MySQL can read simple and complex  queries and write operations.\n\x00 Provides  strong  indexing  support.\n\x00 Provides support  for secured connections.\n\x00 Provides  powerful  data encryption  and accuracy.\n\x00 Provides cross-platform  compatibility.\n\x00 Provides  minimized  code repetition.\nQueries  can  be understood  as the commands  which  interacts  with  database  tables  to work  \naround with data. We will be using MySQL for the experiments  that follow.\n3'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 5, 'page_label': '6'}, page_content='Experiment  1: Creating  a Database  with  Tables\nDesign  a database  and create  required  tables  in it.\nLet us create a database  named ‘College’, with two tables – Student details and Course  details.\nSee  Existing  Databases:\nSyntax: SHOW DATABASES;\nThis displays  information  of all the existing  databases  in the server.\nScreenshot of output to the ‘show databases’ query, displaying list of existing databases.\nCreating  a Database:\nSyntax: CREATE database database_name;\nThis creates a new database  with the name ‘database_name’ in the MySQL server.\nScreenshot of output to the ‘create database’ query, creating the new database.\nUsing  the Database:  \nSyntax: USE database_name;\nThis sets the database  as the current  database  in the MySQL  server.\nScreenshot of output to the ‘use database’ query, setting the current database.\nSee  Existing  Tables  in the  Database:\nSyntax: SHOW TABLES;\nThis shows  all the tables  in the selected database  as information.\n4'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 6, 'page_label': '7'}, page_content='Screenshot of output to the ‘show tables’ query, displaying if there are any pre existing tables in the database.\nAn empty set means,  there are no tables existing  in our database.\nCreating  Tables:\nSyntax:\nCREATE TABLE table_name(column1, column2, column3..); \nThis statement  creates  a new table with the given columns.\nScreenshot of outputs to the ‘create table’ query, creating the new table with given columns.\nDescribing  the  Table:  \nSyntax:\nDESCRIBE table_name;\nThis describes the columns of the table_name with respect to Field, Type, Null, Key, Default, \nExtra.\nOutputs to the ‘describe table’ query, giving information about the table, its columns, datatypes and constraints.\n5'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 7, 'page_label': '8'}, page_content='Inserting  Values:\nSyntax:\nINSERT INTO table_name (column1, column2, column3 . . ) VA L U E S ( v a l u e 1 , value2, . . ); \nThis statement  inserts  a new record  into a table with specified  values.\nScreenshots of outputs to the ‘insert into table’ query, that inserts new records into the table.\nDisplay  All Records  of the Table:  \nSyntax:\nSELECT * FROM table_name ;\nThis query  retrieves all records  from  the table.\nScreenshot of outputs to the ‘select * from…’ query, retrieves all records from the table.\n6'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 8, 'page_label': '9'}, page_content='Experiment  2: Primary  key  and  Foreign  Key  Integrity\nPrimary  Key\nA MySQL Primary  Key is a unique column/field  in a table that should not contain  duplicate or \nNULL values and is used to identify  each record in the table uniquely. The role of the primary  \nkey  constraint  is to maintain  the  integrity  of the  database  by preventing  duplicate  and  null  \nvalues in the key column. A table can only have one primary key.\nPrimary  key  constraint  can  be set either  while  creating  a table  or by using  the  ALTER\ncommand.\n1.   Using CREATE:\nSyntax:\nCREATE TABLE table_name (column1 datatype primary key, column2 datatype);\nScreenshot of output when constraint primary key is given using CREATE command.\n2.   Using ALTER:\nSyntax:\nALTER TABLE table_name ADD PRIMARY KEY (column_name);\nScreenshot of output when constraint primary key is given using ALTER command.\nForeign  Key\nA Foreign  Key is a field in one table, that refers to the Primary  Key in another  table. The table \nwith  the foreign  key is called  the child  table,  and the table  with  the primary  key is called  the \nreferenced  or parent  table.\n7'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 9, 'page_label': '10'}, page_content='Screenshot of output when constraint foreign key is given to a field.\nNOT NULL\nBy default,  a column  can hold NULL values.  The NOT NULL constraint  enforces  a column  to \nNOT accept NULL values. This enforces a field to always contain a value, which means that you \ncannot  insert  a new record,  or update  a record  without  adding  a value  to this field.\nScreenshot of output when constraint NOT NULL is given to a field.\nNow, the field ‘id’ can never be a null value, that means, it must always hold a value.\n8'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 10, 'page_label': '11'}, page_content='Experiment 3: ALTER, UPDATE, DELETE\nALTER\nThis statement  can be used to alter the table, that is, adding  or deleting  columns  of the table.\nSyntax:\nALTER TABLE table_name ADD(column1, column2, column3..); \nThis statement  adds  columns  to the existing  table.\nScreenshot of output when ALTER TABLE command is used to add columns.\nSyntax:\nALTER TABLE table_name DROP(column1);\nThis statement  deletes  specified  columns  from the existing  table.\nScreenshot of output when ALTER TABLE command is used to drop columns.\nUPDATE\nThe UPDATE statement is used to modify the existing records in a table.\nSyntax:\nUPDATE table_name SET column1 = value1, column2 = value2,.. WHERE condition;\nThis statement  updates  records  in the table with the new given values  for the columns.\n9'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 11, 'page_label': '12'}, page_content='Screenshots of outputs when UPDATE command is used to modify records in the table. \nWHERE clause in MySQL queries is used to filter rows for a specific condition. \nDELETE\nThe DELETE  statement  is used to delete existing records  in a table.\nSyntax:\nDELETE FROM table_name WHERE condition;\nScreenshot of output when DELETE command is used to delete records from the table.\n10'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 12, 'page_label': '13'}, page_content='EXPERIMENT 4: JOINS in SQL\nJOINS\nJoins  are  the  joining  of  two  or  more  database  tables  to  fetch  data  based  on  a common  \nfield. There  are various  types  of joins with different  names  in different  databases.  Commonly  \nknown joins are self join, left join, right join and inner join.\nLet us perform different JOIN operations  on our two tables, ‘Student’ and ‘Course’. Our tables \nare as follows:\nScreenshot of tables that we have in our database, i.e., Student and Course\n1.  Regular  Join:\nIt is the join which gets all the records  from both the tables which exactly  match the given \ncondition.\nScreenshot of output when JOIN command is used to join tables.\n2.  Left  Join:\nIt is the join which gets all the records that match the given condition,  and also fetch all \nthe records  from the left table.\nScreenshot of output when LEFT JOIN command is used to join tables.\n11'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 13, 'page_label': '14'}, page_content='3.  Right  Join:\nIt is the join which gets all the records that match the given condition,  and also fetch all \nthe records  from  the right  table.\nScreenshot of output when RIGHT JOIN command is used to join tables.\n4.  Inner  Join:\nThe INNER JOIN keyword selects records that have matching  values in both tables.\nScreenshot of output when INNER JOIN command is used to join tables.\n12'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 14, 'page_label': '15'}, page_content='EXPERIMENT 5: Functions in SQL\nQueries to implement different functions in SQL: MAX(), MIN(), A VG() and COUNT()\nLet us consider our ‘Students’ table. We will perform these function operations  on the CGPA \ncolumn.\nScreenshot shows our table Student, holding student details including the CGPA column.\n1.  MAX()\nIt is used to get the maximum  numeric  value of a particular  column  of table.\nAbove screenshots show outputs when MAX() command is used on the ‘Student’ table.\n2.  MIN()\nIt is used to get the minimum  numeric  value of a particular column  of table.\nAbove screenshots show outputs when MIN() command is used on the ‘Student’ table.\n3.  A VG()\nThe AV G ( ) function  returns the average value of a numeric column.\n13'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 15, 'page_label': '16'}, page_content='Above screenshots show outputs when A VG() command is used on the ‘Student’ table.\n4.  COUNT()\nIt returns  the number  of records  in the table or column.\nAbove screenshots show outputs when COUNT() command is used on the ‘Student’ table.\n14'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 16, 'page_label': '17'}, page_content='Experiment  6: Integrity  Constraints\n1.  Primary  Key:\nPrimary Key is a unique column/field  in a table that should not contain duplicate  or NULL \nvalues  and is used to identify  each  record  in the table uniquely.\nScreenshot of output when constraint primary key is given.\n2.  Foreign  Key:\nA Foreign  Key is a field in one table, that refers to the Primary  Key in another  table. The table \nwith  the foreign  key is called  the child  table,  and the table  with  the primary  key is called  the \nreferenced  or parent  table.\nScreenshot of output when constraint foreign key is given to a field.\n3.  NOT NULL:\nThe NOT NULL constraint enforces a column to NOT accept NULL values, and thus enforces a \nfield to always  contain  a value,  which  means  that you cannot  insert  a new record,  or update  a \nrecord  without  adding  a value to this field.\nScreenshot of output when constraint NOT NULL is given to a field.\n15'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 17, 'page_label': '18'}, page_content='4.   UNIQUE:\nEnsures  that all values in a column  are different.\nScreenshot of output when UNIQUE constraint is given to a field.\n5.   DEFAULT:\nSets a default value for a column if no value is specified.\nScreenshot of output when DEFAULT constraint is given to a field.\n6.   CHECK:\nEnsures  that the values in a column satisfies a specific condition.  \nOur table ‘Students’ is as follows.\nScreenshot shows our table Student, holding student details.\nAdding CHECK Constraint,\nScreenshot of output when CHECK constraint is given to a field, and it satisfies the condition.\nSince condition  of age being greater  than 18 is satisfied,  we get no error. On the other hand,\nScreenshot of output when CHECK constraint is given to a field, and it does not satisfy the condition.\nWe get an error when a constraint  of age being greater  than 20 is given, since, not all records  \nin the table satisfy  this condition.\n16'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 18, 'page_label': '19'}, page_content='Experiment  7: Implementation  of Views\nWhat  is a View?\nA view is a virtual table based on the result-set  of an SQL statement.  A view contains  rows and \ncolumns,  just like a real table. The fields in a view are fields from one or more real tables in the \ndatabase.  You can add SQL statements  and functions  to a view  and present  the data  as if the \ndata were coming  from one single table.\nA view is created with the CREATE VIEW statement.\nSyntax:\nCREATE VIEW view_name AS \nSELECT column1, column2, ... \nFROM table_name\nWHERE condition;\nExample 1:\nCreating a view with IDs and Names of ECE students.\nScreenshot of output when ‘CREATE VIEW…’  statement is used on a table with a condition.\nExample 2:\nCreating a view with ID, Name, Branch and CGPA of students having a CGPA greater than 8.\nScreenshot of output when ‘CREATE VIEW…’  statement is used on a table with another condition.\n17'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 19, 'page_label': '20'}, page_content='Experiment  8: Implementation  of Triggers\nWhat  is a Trigger?\nA Trigger is a block of SQL code that is automatically executed  (fired) when a specified event \noccurs on a table, such as INSERT, UPDATE, or DELETE.\nPurpose  of Triggers:\n· Enforce  business  rules.\n· Maintain  audit logs.\n· Automatically  update  dependent  data.\nSyntax:\nCREATE TRIGGER trigger_name\nBEFORE | AFTER INSERT | UPDATE | DELETE \nON table_name\nFOR EACH ROW \nBEGIN\n-- SQL statements\nEND;\nExample  1: \nCreating  a Trigger:\n18'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 20, 'page_label': '21'}, page_content='Creating  an  Update  trigger:\nCreating  a Delete  Trigger:\n19'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 21, 'page_label': '22'}, page_content="Experiment  9: Referential  Integrity\nWhat is a REFERENTIAL INTEGRITY ?\nReferential  Integrity  ensures  that the relationship  between  tables  remains  consistent.  It is \nmaintained using the FOREIGN  KEY constraint,  which enforces a link between data in two \ntables.  The child table depends  on the parent  table  for valid entries.\nFor example,  in a college  database,  the 'Student'  table (child)  depends  on the 'Department'  table \n(parent).  A student's  department  ID must  match  an existing  department  ID in the Department  \ntable.\nKey options  in Referential  Integrity:\n· ON DELETE RESTRICT – Prevents deletion of parent records if dependent child records  exist.\n· ON DELETE CASCADE – Automatically deletes child records when the parent is deleted.\n· ON UPDATE CASCADE – Updates the child record if the parent key is modified. \nDELETE CASCADE:\n20"),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 22, 'page_label': '23'}, page_content='UPDATE CASCADE:\n21'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 23, 'page_label': '24'}, page_content='Experiment  10 : Creating  Users  And  Assigning  Roles\nA Database  User  is an entity  (person  or process)  that connects  to the database  to perform  \noperations  like querying,  inserting,  or modifying  data. Each user has a username  and password  \nfor authentication.\nDatabase  Roles  are collections  of privileges  that can be assigned  to one or more users.  Instead  \nof granting  privileges  individually  to each user, roles simplify  the process  by grouping  \npermissions  together.\nPrivileges  are permissions  granted  to users  or roles to perform  specific  actions  on database  \nobjects. They can be classified into:\n· System  Privileges  – Allow  actions  such as creating  tables or databases.\n· Object Privileges – Allow actions like SELECT, INSERT, UPDATE, DELETE on specific tables.\nCommon Commands:\n· CREATE USER – Creates a new database user.\n· CREATE ROLE – Creates a reusable set of privileges.\n· GRANT – Assigns privileges or roles to users.\n· REVOKE – Removes privileges or roles from users. \nCreate  New  Database  Users:\nGrant Privileges to Users:\n22'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 24, 'page_label': '25'}, page_content='Verify Privileges to Users:\nCreate roles:\n23'),
#  Document(metadata={'producer': 'macOS Version 15.7.1 (Build 24G231) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20251106044206Z00'00'", 'title': 'aryadbmsreport', 'moddate': "D:20251106044206Z00'00'", 'source': 'aryadbmsreport.pdf', 'total_pages': 26, 'page': 25, 'page_label': '26'}, page_content='Conclusion\nSQL  is a powerful  tool  for  managing  relational  databases.  This  report  covered  essential  \nconcepts   like  table  creation,   constraints   (Primary   Key,  Foreign   Key,  NOT  NULL),   and \noperations (ALTER, UPDATE, DELETE)  to ensure data integrity and consistency. Joins enable \ncombining data from multiple tables, while functions like MAX(), MIN(), A VG(), and COUNT() \nsimplify  data  analysis.  Integrity  constraints  and  views  further  enhance  data  quality,  security,  \nand performance.  These  SQL features  collectively  empower  developers  to create efficient  and \nrobust  database  systems.\n24')]

# %%
 type(pdfReader)
# Out:
# list

# %%
## Web based loader
from langchain_community.document_loaders import WebBaseLoader 
import bs4
loader = WebBaseLoader(web_paths=("https://www.example.com",),
    bs_kwargs = dict(parse_only  = bs4.SoupStrainer(
        class_=("post-title", "post-content" , "post-header")
    ) ) )
loader.load()
# Out:
# [Document(metadata={'source': 'https://www.example.com'}, page_content='')]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_community/utilities/arxiv.py:220, in ArxivAPIWrapper.lazy_load(self, query)
#     219 try:
# --> 220     doc_file_name: str = result.download_pdf()
#     221     with fitz.open(doc_file_name) as doc_file:
#
# Cell In[63], line 5, in <lambda>(self, dirpath, filename)
#       3 # Patch the download domain globally
#       4 arxiv.Result.download_pdf = lambda self, dirpath=".", filename=None: \
# ----> 5     self._download_pdf_with_domain(dirpath, filename, download_domain="arxiv.org")
#       7 # Helper method (monkey patch)
#
# Cell In[63], line 15, in _download_pdf_with_domain(self, dirpath, filename, download_domain)
#      14 path = os.path.join(dirpath, filename)
# ---> 15 pdf_url = self.pdf_url.replace("arxiv.org", download_domain)
#      16 written_path, _ = urlretrieve(pdf_url, path)
#
# AttributeError: 'NoneType' object has no attribute 'replace'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 32
#      24 # Your query
#      25 loader = ArxivLoader(
#      26     query="1706.03762",
#      27     load_max_docs=2,
#      28     # These help avoid issues
#      29     load_all_available_metadata=True,
#      30 )
# ---> 32 docs = loader.load()
#      33 print(len(docs))
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/document_loaders/base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_community/document_loaders/arxiv.py:149, in ArxivLoader.lazy_load(self)
#     147 def lazy_load(self) -> Iterator[Document]:
#     148     """Lazy load Arvix documents"""
# --> 149     yield from self.client.lazy_load(self.query)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_community/utilities/arxiv.py:223, in ArxivAPIWrapper.lazy_load(self, query)
#     221     with fitz.open(doc_file_name) as doc_file:
#     222         text: str = "".join(page.get_text() for page in doc_file)
# --> 223 except (FileNotFoundError, fitz.fitz.FileDataError) as f_ex:
#     224     logger.debug(f_ex)
#     225     continue
#
# AttributeError: module 'fitz' has no attribute 'fitz'
