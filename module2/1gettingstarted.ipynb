# %%
from langchain_community.llms import Ollama
llm = Ollama(model="gemma:2b")

# %%
response = llm.invoke("write a short poem about india")
print(response)
# Out:
# Land of ancient tales,
# Where history's echoes crawl.
# Spice-stained roads and vibrant sight,
# A tapestry of day and night.
#
# From Himalayas' snow-capped heights,
# To desert sands stretching wide and deep.
# A symphony of languages sing,
# A vibrant melody that will never wing.
#
# In temples old, and vibrant art,
# A legacy that warms the heart.
# A land of contrasts, old and new,
# A vibrant tapestry, rich and true.

# %%
llm.invoke("what is generative ai")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 llm.invoke("what is generative ai")
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:373, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     362 @override
#     363 def invoke(
#     364     self,
#    (...)
#     369     **kwargs: Any,
#     370 ) -> str:
#     371     config = ensure_config(config)
#     372     return (
# --> 373         self.generate_prompt(
#     374             [self._convert_input(input)],
#     375             stop=stop,
#     376             callbacks=config.get("callbacks"),
#     377             tags=config.get("tags"),
#     378             metadata=config.get("metadata"),
#     379             run_name=config.get("run_name"),
#     380             run_id=config.pop("run_id", None),
#     381             **kwargs,
#     382         )
#     383         .generations[0][0]
#     384         .text
#     385     )
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:784, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     775 @override
#     776 def generate_prompt(
#     777     self,
#    (...)
#     781     **kwargs: Any,
#     782 ) -> LLMResult:
#     783     prompt_strings = [p.to_string() for p in prompts]
# --> 784     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:1006, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     987 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     988     run_managers = [
#     989         callback_manager.on_llm_start(
#     990             self._serialized,
#    (...)
#    1004         )
#    1005     ]
# -> 1006     return self._generate_helper(
#    1007         prompts,
#    1008         stop,
#    1009         run_managers,
#    1010         new_arg_supported=bool(new_arg_supported),
#    1011         **kwargs,
#    1012     )
#    1013 if len(missing_prompts) > 0:
#    1014     run_managers = [
#    1015         callback_managers[idx].on_llm_start(
#    1016             self._serialized,
#    (...)
#    1023         for idx in missing_prompt_idxs
#    1024     ]
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:810, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     799 def _generate_helper(
#     800     self,
#     801     prompts: list[str],
#    (...)
#     806     **kwargs: Any,
#     807 ) -> LLMResult:
#     808     try:
#     809         output = (
# --> 810             self._generate(
#     811                 prompts,
#     812                 stop=stop,
#     813                 # TODO: support multiple run managers
#     814                 run_manager=run_managers[0] if run_managers else None,
#     815                 **kwargs,
#     816             )
#     817             if new_arg_supported
#     818             else self._generate(prompts, stop=stop)
#     819         )
#     820     except BaseException as e:
#     821         for run_manager in run_managers:
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_community/llms/ollama.py:437, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     435 generations = []
#     436 for prompt in prompts:
# --> 437     final_chunk = super()._stream_with_aggregation(
#     438         prompt,
#     439         stop=stop,
#     440         images=images,
#     441         run_manager=run_manager,
#     442         verbose=self.verbose,
#     443         **kwargs,
#     444     )
#     445     generations.append([final_chunk])
#     446 return LLMResult(generations=generations)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_community/llms/ollama.py:349, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     340 def _stream_with_aggregation(
#     341     self,
#     342     prompt: str,
#    (...)
#     346     **kwargs: Any,
#     347 ) -> GenerationChunk:
#     348     final_chunk: Optional[GenerationChunk] = None
# --> 349     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     350         if stream_resp:
#     351             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_community/llms/ollama.py:194, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     186 def _create_generate_stream(
#     187     self,
#     188     prompt: str,
#    (...)
#     191     **kwargs: Any,
#     192 ) -> Iterator[str]:
#     193     payload = {"prompt": prompt, "images": images}
# --> 194     yield from self._create_stream(
#     195         payload=payload,
#     196         stop=stop,
#     197         api_url=f"{self.base_url}/api/generate",
#     198         **kwargs,
#     199     )
#
# File ~/udemy/venv/lib/python3.10/site-packages/requests/models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     860 """Iterates over the response data, one line at a time.  When
#     861 stream=True is set on the request, this avoids reading the
#     862 content at once into memory for large responses.
#     863
#     864 .. note:: This method is not reentrant safe.
#     865 """
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#     873         chunk = pending + chunk
#
# File ~/udemy/venv/lib/python3.10/site-packages/requests/utils.py:562, in stream_decode_response_unicode(iterator, r)
#     559     return
#     561 decoder = codecs.getincrementaldecoder(r.encoding)(errors="replace")
# --> 562 for chunk in iterator:
#     563     rv = decoder.decode(chunk)
#     564     if rv:
#
# File ~/udemy/venv/lib/python3.10/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/udemy/venv/lib/python3.10/site-packages/urllib3/response.py:1063, in HTTPResponse.stream(self, amt, decode_content)
#    1047 """
#    1048 A generator wrapper for the read() method. A call will block until
#    1049 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1060     'content-encoding' header.
#    1061 """
#    1062 if self.chunked and self.supports_chunked_reads():
# -> 1063     yield from self.read_chunked(amt, decode_content=decode_content)
#    1064 else:
#    1065     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/udemy/venv/lib/python3.10/site-packages/urllib3/response.py:1219, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1216     amt = None
#    1218 while True:
# -> 1219     self._update_chunk_length()
#    1220     if self.chunk_left == 0:
#    1221         break
#
# File ~/udemy/venv/lib/python3.10/site-packages/urllib3/response.py:1138, in HTTPResponse._update_chunk_length(self)
#    1136 if self.chunk_left is not None:
#    1137     return None
# -> 1138 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139 line = line.split(b";", 1)[0]
#    1140 try:
#
# File ~/udemy/venv/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["input"],
    template=(
        "You are an expert AI engineer. "
        "Provide the best possible answer.\n\n"
        "Question:\n{input}"
    )
)
prompt
# Out:
# PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='You are an expert AI engineer. Provide the best possible answer.\n\nQuestion:\n{input}')

# %%
## using this prompt with the llm model 
chain = prompt | llm
response = chain.invoke({"input" : "can u tell me about langsmith"})
print(response)
# Out:
# Sure, I can help with that! Langsmith is an open-source software project focused on building a comprehensive and flexible natural language processing (NLP) toolkit with pre-trained and fine-tuning capabilities. It aims to provide a unified platform for NLP tasks, including text generation, translation, sentiment analysis, question answering, and more.
#
# Here's a breakdown of Langsmith's key features:
#
# **Pre-trained Models:**
#
# * Langsmith comes with a variety of pre-trained models for various NLP tasks, including English, French, German, and Spanish. These pre-trained models have been trained on massive datasets and can offer state-of-the-art performance.
#
# **Fine-tuning Capabilities:**
#
# * The project provides fine-tuning tools for pre-trained models, allowing you to customize them for your specific task. This enables you to optimize the models for your particular data and achieve optimal performance.
#
# **Unified Platform:**
#
# * Langsmith integrates various NLP modules and tasks, including core NLP tasks, machine learning libraries, and pre-trained models, into a single, unified platform. This simplifies the NLP development process and reduces the need for multiple tools and libraries.
#
# **Benefits of Langsmith:**
#
# * **Comprehensive:** Langsmith provides a comprehensive set of tools for NLP tasks, covering various domains.
# * **Flexible:** It offers customizable pre-trained models and fine-tuning capabilities, allowing you to tailor the models to your specific needs.
# * **Open Source:** The project is open-source, enabling community contributions and collaboration.
# * **Active Community:** Langsmith has a large and active community of developers and users, providing support, resources, and knowledge sharing.
#
# **Use Cases for Langsmith:**
#
# * Natural language processing (NLP) research and development
# * Enterprise NLP applications
# * Educational NLP tools
# * Content creation and marketing automation
#
# **Where to Learn More:**
#
# * Official website: langsmith.ai
# * Documentation: docs.langsmith.ai
# * GitHub repository: github.com/langsmith-ai/langsmith
#
# **Additionally, I can provide specific examples of how to use Langsmith for different NLP tasks, but I would need more context and your desired application.**

# %%
## string output parser

from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt|llm|output_parser

response = chain.invoke({"input":"can you tell me about langsmith"})
print(response)
# Out:
# Sure, here's an overview of Langsmith:
#
# **Langsmith** is a next-generation language model specifically designed to operate within **The Metaverse**, a digital universe built on blockchain technology. It offers the following key features:
#
# * **Metaverse-native:** It is trained on a massive dataset of text and code from the Metaverse, including books, music, and other digital assets.
# * **Zero-knowledge capabilities:** It can perform computations and answer questions without revealing sensitive data.
# * **Multimodal understanding:** It can process and generate language, images, and audio simultaneously, enabling it to understand the context of a given interaction.
# * **Customizable:** It can be tailored to specific use cases by fine-tuning on relevant datasets.
# * **Efficient:** It utilizes a novel architecture that significantly improves the efficiency of language processing.
#
# **Here's how Langsmith can be used:**
#
# * **Content creation:** It can generate various creative content, including stories, poems, scripts, and more.
# * **Language translation:** It can translate text between multiple languages with near-perfect accuracy.
# * **Question answering:** It can provide answers to a wide range of questions, including factual, creative, and technical inquiries.
# * **Natural language processing:** It can be used in various natural language processing tasks, such as sentiment analysis, sentiment classification, and text summarization.
# * **Metaverse interaction:** It can interact with the Metaverse through voice and text, allowing users to engage in immersive experiences.
#
# **Overall, Langsmith is a powerful AI model that offers significant potential for various applications in the Metaverse, including:**
#
# * **Content generation**
# * **Language translation**
# * **Question answering**
# * **Natural language processing**
# * **Metaverse interaction**
#
# **Additional points to consider:**
#
# * Langsmith is currently in the beta phase of development, and its capabilities are constantly evolving.
# * It is accessible through a variety of SDKs and APIs, making it easy to integrate into different metaverse platforms.
# * The model is highly secure and responsible, with built-in mechanisms to protect against bias and misuse.
#
# I hope this provides a comprehensive overview of Langsmith. If you have any further questions, please let me know.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

# %%
FULL FLOW OF BUILDING A SIMPLE GEN AI APPPLICATION

# %%
import os
from dotenv import load_dotenv
load_dotenv()


os.environ['LANGCHAIN_API_KEY'] = os.getenv("LANGCHAIN_API_KEY")
os.environ['GEMINI_API_KEY'] = os.getenv("GEMINI_API_KEY")
os.environ['LANGCHAIN_PROJECT']  = os.getenv("LANGCHAIN_PROJECT")

# %%
##IMPORTED THE GOOGLE GEMINI MODEL

from langchain_google_genai import ChatGoogleGenerativeAI

geminiLLM = ChatGoogleGenerativeAI(
   model="gemini-pro",
    api_key=os.environ["GEMINI_API_KEY"]
)

geminiLLM
# Out:
# ChatGoogleGenerativeAI(profile={}, model='models/gemini-pro', google_api_key=SecretStr('**********'), client=<google.ai.generativelanguage_v1beta.services.generative_service.client.GenerativeServiceClient object at 0x1104994b0>, default_metadata=(), model_kwargs={})

# %%
from langchain_core.prompts import ChatPromptTemplate
 
prompt = ChatPromptTemplate.from_messages([
    ("system" , "You are modi , the Prime Minister of India"),
    ("user" , "{input}")
])


## making the chain which connects prompt with llm
chain = prompt | geminiLLM


## running the chain 

response = chain.invoke({"input" : "explain the rag architecture in 1 sentence"})
print(response)
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 16.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 32.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In[43], line 15
#      10 chain = prompt | geminiLLM
#      13 ## running the chain
# ---> 15 response = chain.invoke({"input" : "explain the rag architecture in 1 sentence"})
#      16 print(response)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/runnables/base.py:3129, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3127                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3128             else:
# -> 3129                 input_ = context.run(step.invoke, input_, config)
#    3130 # finish the root run
#    3131 except BaseException as e:
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:2138, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2135         msg = "Tools are already defined.code_execution tool can't be defined"
#    2136         raise ValueError(msg)
# -> 2138 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)
#     391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)
#    1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:2295, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    2293 if "max_retries" not in kwargs:
#    2294     kwargs["max_retries"] = self.max_retries
# -> 2295 response: GenerateContentResponse = _chat_with_retry(
#    2296     request=request,
#    2297     **kwargs,
#    2298     generation_method=self.client.generate_content,
#    2299     metadata=self.default_metadata,
#    2300 )
#    2301 return _response_to_result(response)
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:269, in _chat_with_retry(generation_method, **kwargs)
#     264         raise
#     266 params = {
#     267     k: v for k, v in kwargs.items() if k in _allowed_params_prediction_service
#     268 }
# --> 269 return _chat_with_retry(**params)
#
# File ~/udemy/venv/lib/python3.10/site-packages/tenacity/__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~/udemy/venv/lib/python3.10/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/udemy/venv/lib/python3.10/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/udemy/venv/lib/python3.10/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/udemy/venv/lib/python3.10/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~/udemy/venv/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/udemy/venv/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/udemy/venv/lib/python3.10/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/udemy/venv/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:243, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     240 @retry_decorator
#     241 def _chat_with_retry(**kwargs: Any) -> Any:
#     242     try:
# --> 243         return generation_method(**kwargs)
#     244     except FailedPrecondition as exc:
#     245         if "location is not supported" in exc.message:
#
# File ~/udemy/venv/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:869, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     866 self._validate_universe_domain()
#     868 # Send the request.
# --> 869 response = rpc(
#     870     request,
#     871     retry=retry,
#     872     timeout=timeout,
#     873     metadata=metadata,
#     874 )
#     876 # Done; return the response.
#     877 return response
#
# File ~/udemy/venv/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/udemy/venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/udemy/venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~/udemy/venv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File ~/udemy/venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/udemy/venv/lib/python3.10/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/udemy/venv/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.
